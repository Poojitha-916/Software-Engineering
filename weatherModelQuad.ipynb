# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojitha-916/Software-Engineering/blob/sftlab/weatherModelQuad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quadratic Formula: ax^2 + bx + c = 0
import math

# Hard-coded coefficients
a = 1
b = -3
c = 2

# Quadratic formula solution
def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant > 0:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return root1, root2
    elif discriminant == 0:
        root = -b / (2*a)
        return root, None
    else:
        return None, None  # No real roots

# %%
# Get coefficients from user input
a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))

# Solve and print the results
roots = solve_quadratic(a, b, c)
print("Roots (user input):", roots)
# Out:
# Enter coefficient a: 1
# Enter coefficient b: 2
# Enter coefficient c: -1
# Roots (user input): (0.41421356237309515, -2.414213562373095)

# %%
# Read coefficients from a file
def read_from_file(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
    coefficients = [tuple(map(float, line.strip().split(','))) for line in lines]
    return coefficients

# %%
# Example: Solve for a single set of inputs
coefficients = read_from_file('/content/input1.txt')
a, b, c = coefficients[0]  # Access the first (and only) element using index 0
roots = solve_quadratic(a, b, c)
print("Roots (file input - single set):", roots)
# Out:
# Roots (file input - single set): (None, None)

# %%
with open('/content/input1.txt', 'w') as file:
    file.write("2,-2,10\n")

# %%
# Solve for all sets in the file
for idx, (a, b, c) in enumerate(coefficients):
    roots = solve_quadratic(a, b, c)
    print(f"Roots (set {idx+1}): {roots}")
# Out:
# Roots (set 1): (None, None)
